# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import GridSearchCV,StratifiedKFold

# %%
df = pd.read_csv("final_dataset.csv")
df.head()
# Out:
#          Date        Open        High         Low       Close    Volume  \
# 0  2021-05-10  879.203179  882.739915  871.018739  873.399231  13941237
# 1  2021-05-11  868.320883  878.999155  866.053671  876.550659  13478264
# 2  2021-05-12  875.167680  876.437264  864.693420  867.481995  13177961
# 3  2021-05-14  874.238087  880.563458  864.239974  878.432373  13291616
# 4  2021-05-17  878.432380  890.289563  875.303667  888.883972  11873078
#
#      Return        MA10        MA20        MA50  MA_Cross  Volatility  \
# 0 -0.002873  888.235583  880.610001  917.756665         0    0.014570
# 1  0.003608  885.719043  879.501361  916.937769         0    0.014433
# 2 -0.010346  881.903418  879.546701  915.596970         0    0.012165
# 3  0.012623  877.969897  879.671393  913.719312         0    0.012255
# 4  0.011898  876.421423  880.035269  912.581653         0    0.012460
#
#    Volume_Change  Volume_MA20  High_Volume  Price_Change  Momentum_5  \
# ...

# %%
df.replace([np.inf, -np.inf], np.nan, inplace=True)

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Date             0
# Open             0
# High             0
# Low              0
# Close            0
# Volume           0
# Return           0
# MA10             0
# MA20             0
# MA50             0
# MA_Cross         0
# Volatility       0
# Volume_Change    0
# Volume_MA20      0
# High_Volume      0
# Price_Change     0
# Momentum_5       0
# Momentum_10      0
# Target           0
# dtype: int64

# %%
df.shape
# Out:
# (1188, 19)

# %%
y = df['Target']
X = df.drop(['Target','Date'], axis=1)

# %%
split = int(len(X) * 0.8)

X_train = X[:split]
X_test = X[split:]

y_train = y[:split]
y_test = y[split:]

# %%
model = RandomForestClassifier(
    n_estimators=200,
    max_depth=8,
    random_state=42
)

model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=8, n_estimators=200, random_state=42)

# %%
pred = model.predict(X_test)

# %%
accuracy = accuracy_score(y_test, pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.5378151260504201

# %%
print(confusion_matrix(y_test, pred))
print(classification_report(y_test, pred))
# Out:
# [[64 54]
#  [56 64]]
#               precision    recall  f1-score   support
#
#            0       0.53      0.54      0.54       118
#            1       0.54      0.53      0.54       120
#
#     accuracy                           0.54       238
#    macro avg       0.54      0.54      0.54       238
# weighted avg       0.54      0.54      0.54       238

# %%
importance = model.feature_importances_
features = X.columns

imp_df = pd.DataFrame({
    'Feature': features,
    'Importance': importance
}).sort_values(by='Importance', ascending=False)

print(imp_df.head(10))
# Out:
#           Feature  Importance
# 11  Volume_Change    0.098374
# 10     Volatility    0.075710
# 4          Volume    0.074937
# 15     Momentum_5    0.070372
# 5          Return    0.069681
# 16    Momentum_10    0.067938
# 12    Volume_MA20    0.065437
# 14   Price_Change    0.061479
# 2             Low    0.060596
# 8            MA50    0.060329

# %%
plt.figure(figsize=(8,5))
plt.barh(imp_df['Feature'][:10], imp_df['Importance'][:10])
plt.gca().invert_yaxis()
plt.title("Top Important Features")
plt.show()

# %%
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [5, 8, 12],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# %%
cv = StratifiedKFold(n_splits=5, shuffle=True)

# %%
rf = RandomForestClassifier(random_state=42)

grid = GridSearchCV(
    estimator=rf,
    param_grid=param_grid,
    cv=cv,
    n_jobs=-1,
    verbose=2
)

grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=None, shuffle=True),
#              estimator=RandomForestClassifier(random_state=42), n_jobs=-1,
#              param_grid={'max_depth': [5, 8, 12], 'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [100, 200, 300]},
#              verbose=2)

# %%
print("\nBest parameters found: ", grid.best_params_)
# Out:
# Best parameters found:  {'max_depth': 12, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 100}

# %%
best_model = grid.best_estimator_

# %%
best_model.fit(X_train,y_train)
# Out:
# RandomForestClassifier(max_depth=12, min_samples_leaf=2, min_samples_split=10,
#                        random_state=42)

# %%
print(accuracy_score(y_test,best_model.predict(X_test)))
# Out:
# 0.5336134453781513

# %%
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.53      0.57      0.55       118
#            1       0.54      0.50      0.52       120
#
#     accuracy                           0.53       238
#    macro avg       0.53      0.53      0.53       238
# weighted avg       0.53      0.53      0.53       238

# %%
importance = best_model.feature_importances_
features = X.columns

imp = pd.DataFrame({
    'Feature': features,
    'Importance': importance
}).sort_values(by='Importance', ascending=False)
plt.figure(figsize=(8,5))
plt.barh(imp['Feature'][:10], imp['Importance'][:10])
plt.gca().invert_yaxis()
plt.title("Top Influential Market Indicators")
plt.show()

# %%
up_predictions = pred == 1
correct_up = (pred == y_test) & (pred == 1)

precision_up = correct_up.sum() / up_predictions.sum()
print("Trading Precision (UP predictions):", precision_up)
# Out:
# Trading Precision (UP predictions): 0.5405405405405406

# %%
latest = X.iloc[-1:]
prediction = best_model.predict(latest)

if prediction[0] == 1:
    print("Model Signal: BUY (Price likely to go up tomorrow)")
else:
    print("Model Signal: SELL (Price likely to go down tomorrow)")
# Out:
# Model Signal: BUY (Price likely to go up tomorrow)

# %%
import pickle

with open("model.pkl", "wb") as f:
    pickle.dump(best_model, f)

print("Model saved!")
# Out:
# Model saved!
